# %%
from EllipseFit import FindOriginalBall

# %%
oval = FindOriginalBall('oval.png')

# %%
oval.calculate_original()
# Out:
# ((599, 199), 200)

# %%
oval.graph_to_original(xdir=1)

# %%
test = FindOriginalBall('black.png')

# %%
test.graph_to_original(xdir=1)

# %%
test.calculate_original()
# Out:
# ((122, 88), 29)

# %%
test2 = FindOriginalBall('black2.png')
test2.graph_to_original(xdir=-1)
